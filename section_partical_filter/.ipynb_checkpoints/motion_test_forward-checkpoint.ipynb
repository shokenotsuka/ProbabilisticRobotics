# %%
import sys
sys.path.append("../scripts/")
from robot import *

# %%
import copy

world=World(40.0,0.1)

initial_pose=np.array([0,0,0]).T
robots=[]
r = Robot(initial_pose,sensor=None,agent=Agent(0.1,0.0))

for i in range(10):
    copy_r = copy.copy(r)
    copy_r.distance_until_noise = copy_r.noise_pdf.rvs()
    world.append(copy_r)
    robots.append(copy_r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import pandas as pd
poses = pd.DataFrame([[math.sqrt(r.pose[0]**2+r.pose[1]**2),r.pose[2]] for r in robots],
                     columns=['r','theta'])
poses.transpose()
# Out:
#               0         1         2         3         4         5         6  \
# r      4.460754  4.472882  4.467216  4.470784  4.437492  4.475891  4.460254
# theta  0.098679 -0.047373  0.123773 -0.047085 -0.309385 -0.105543  0.205887
#
#               7         8         9
# r      4.470387  4.474427  4.477636
# theta -0.107835  0.082014  0.128024

# %%
print(poses['theta'].var())
print(poses['r'].mean())
math.sqrt(poses['theta'].var()/poses['r'].mean())
# Out:
# 0.0237184848594543
# 4.466772197241959
# 0.07286963081864449

# %%
world=World(40.0,0.1)

initial_pose=np.array([0,0,0]).T
robots=[]


for i in range(10):
    r = Robot(initial_pose,sensor=None,agent=Agent(0.1,0.0))
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd
poses = pd.DataFrame([[math.sqrt(r.pose[0]**2+r.pose[1]**2),r.pose[2]] for r in robots],
                     columns=['r','theta'])
poses.transpose()
# Out:
#               0         1         2         3         4         5         6  \
# r      4.611417  4.400055  4.662613  4.570136  4.040351  3.892830  3.709897
# theta  0.429798  0.435818  0.004382  0.175250 -0.194428 -0.085953 -0.044659
#
#               7         8         9
# r      3.444662  4.114886  3.715320
# theta  0.163725  0.074026 -0.224878

# %%
print(poses['r'].var())
print(poses['r'].mean())
math.sqrt(poses['r'].var()/poses['r'].mean())
# Out:
# 0.18475979840074067
# 4.116216803223069
# 0.21186275686745157
